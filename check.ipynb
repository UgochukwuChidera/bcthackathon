# %%
import pandas as pd
data = pd.read_csv("unified_metadata.csv")
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   type               100000 non-null  str
#  1   name               100000 non-null  str
#  2   category           100000 non-null  str
#  3   rating_num         100000 non-null  float64
#  4   price_bucket       100000 non-null  str
#  5   popularity_bucket  100000 non-null  str
#  6   location           30000 non-null   str
#  7   author             10000 non-null   str
#  8   price_numeric      60000 non-null   float64
# dtypes: float64(2), str(7)
# memory usage: 6.9 MB
# /tmp/ipykernel_24135/1785515392.py:2: DtypeWarning: Columns (0: author) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("unified_metadata.csv")

# %%
data.head()
# Out:
#       type                                               name  \
# 0  product                                  Jitsu Squad (PS5)
# 1  product  Google WiFi Wall Mount ABS Bracket Holder Shel...
# 2  product  Cables Direct Online, Bulk 18/4 Stranded Condu...
# 3  product  Houseables 4 Oz Plastic Containers with Lids, ...
# 4  product  co2CREA Hard Travel Case Replacement for TP-Li...
#
#                                       category  rating_num price_bucket  \
# 0  PlayStation 5 Consoles, Games & Accessories         4.5         high
# 1              Smart Home: WiFi and Networking         4.6          low
# 2            Security & Surveillance Equipment         4.4    very high
# 3                   Beauty Tools & Accessories         4.6          low
# 4                          Computer Networking         4.5          low
#
#   popularity_bucket location author  price_numeric
# 0          very low      NaN    NaN          39.82
# 1          very low      NaN    NaN          11.99
# ...
